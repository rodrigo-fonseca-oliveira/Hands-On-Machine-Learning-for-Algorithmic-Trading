# %% [markdown]
# <a href="https://www.quantrocket.com"><img alt="QuantRocket logo" src="https://www.quantrocket.com/assets/img/notebook-header-logo.png"></a>
#
# <a href="https://www.quantrocket.com/disclaimer/">Disclaimer</a>

# %% [markdown]
# # Zipline Backtest

# %% [markdown]
# We're ready to run a backtest. Zipline strategies are referenced by the filename without extension; thus, to run the strategy in our `winners.py` file, we use the code `"winners"`.

# %% [markdown]
# Some Zipline backtests can be long-running. You can use the `progress` parameter to tell Zipline to log progress and performance statistics to flightlog periodically during the backtest. In this example, we log progress for each month of the simulation (`progress="M"`). Make sure flightlog is running in a terminal so you can see the progress output, then run the backtest:

# %%
from quantrocket.zipline import backtest
backtest(
    "alpha_factor_zipline_with_trades_qr", 
    start_date="2017-01-01",
    end_date="2023-03-31", 
    progress="M",
    filepath_or_buffer="alpha_factor_zipline_with_trades_qr_zipline_results.csv")

# %% [markdown]
# Zipline returns the backtest results as a CSV. You can use pyfolio, a companion library to Zipline, to look at a tear sheet of performance results:

# %%
import pyfolio as pf
pf.from_zipline_csv("alpha_factor_zipline_with_trades_qr_zipline_results.csv")
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2017-01-04</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2023-03-31</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>74</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>2.475%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>16.462%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>2.858%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>0.87</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>0.54</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.86</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-4.554%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>1.17</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>1.26</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>-0.38</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>6.79</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>1.13</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-0.35%</td>
#     </tr>
#     <tr>
#       <th>Gross leverage</th>
#       <td>0.12</td>
#     </tr>
#     <tr>
#       <th>Daily turnover</th>
#       <td>24.875%</td>
#     </tr>
#     <tr>
#       <th>Alpha</th>
#       <td>0.01</td>
#     </tr>
#     <tr>
#       <th>Beta</th>
#       <td>0.08</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>4.55</td>
#       <td>2020-02-20</td>
#       <td>2020-05-13</td>
#       <td>2020-06-16</td>
#       <td>84</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>4.45</td>
#       <td>2021-06-01</td>
#       <td>2022-10-12</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1.96</td>
#       <td>2018-08-29</td>
#       <td>2019-01-03</td>
#       <td>2019-01-22</td>
#       <td>105</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>1.82</td>
#       <td>2021-02-03</td>
#       <td>2021-05-13</td>
#       <td>2021-05-26</td>
#       <td>81</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>1.75</td>
#       <td>2019-07-16</td>
#       <td>2019-09-03</td>
#       <td>2019-10-21</td>
#       <td>70</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Stress Events</th>
#       <th>mean</th>
#       <th>min</th>
#       <th>max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2018 Bear Market</th>
#       <td>-0.00%</td>
#       <td>-0.55%</td>
#       <td>0.59%</td>
#     </tr>
#     <tr>
#       <th>COVID-19</th>
#       <td>0.01%</td>
#       <td>-1.49%</td>
#       <td>0.88%</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Top 10 long positions of all time</th>
#       <th>max</th>
#     </tr>
#     <tr>
#       <th>column</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Equity(FIBBG00D1WHZD9 [HTZ])</th>
#       <td>1.27%</td>
#     </tr>
#     <tr>
#       <th>Equity(FIBBG000Q1KFH4 [WAL])</th>
#       <td>1.16%</td>
#     </tr>
#     <tr>
#       <th>Equity(FIBBG000BQWPC5 [PCG])</th>
#       <td>1.00%</td>
#     </tr>
#     <tr>
#       <th>Equity(FIBBG00NNW8JK1 [ARCT])</th>
#       <td>0.78%</td>
#     </tr>
#     <tr>
#       <th>Equity(FIBBG0016XJ8S0 [TAL])</th>
#       <td>0.77%</td>
#     </tr>
#     <tr>
#       <th>Equity(FIBBG003T1GM03 [RITM])</th>
#       <td>0.76%</td>
#     </tr>
#     <tr>
#       <th>Equity(FIBBG00LPWLFD4 [FSR])</th>
#       <td>0.75%</td>
#     </tr>
#     <tr>
#       <th>Equity(FIBBG000MHTV89 [EPAM])</th>
#       <td>0.73%</td>
#     </tr>
#     <tr>
#       <th>Equity(FIBBG000CWL0F5 [EXAS])</th>
#       <td>0.71%</td>
#     </tr>
#     <tr>
#       <th>Equity(FIBBG002CV4Q74 [FUBO])</th>
#       <td>0.69%</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Top 10 short positions of all time</th>
#       <th>max</th>
#     </tr>
#     <tr>
#       <th>column</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Top 10 positions of all time</th>
#       <th>max</th>
#     </tr>
#     <tr>
#       <th>column</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Equity(FIBBG00D1WHZD9 [HTZ])</th>
#       <td>1.27%</td>
#     </tr>
#     <tr>
#       <th>Equity(FIBBG000Q1KFH4 [WAL])</th>
#       <td>1.16%</td>
#     </tr>
#     <tr>
#       <th>Equity(FIBBG000BQWPC5 [PCG])</th>
#       <td>1.00%</td>
#     </tr>
#     <tr>
#       <th>Equity(FIBBG00NNW8JK1 [ARCT])</th>
#       <td>0.78%</td>
#     </tr>
#     <tr>
#       <th>Equity(FIBBG0016XJ8S0 [TAL])</th>
#       <td>0.77%</td>
#     </tr>
#     <tr>
#       <th>Equity(FIBBG003T1GM03 [RITM])</th>
#       <td>0.76%</td>
#     </tr>
#     <tr>
#       <th>Equity(FIBBG00LPWLFD4 [FSR])</th>
#       <td>0.75%</td>
#     </tr>
#     <tr>
#       <th>Equity(FIBBG000MHTV89 [EPAM])</th>
#       <td>0.73%</td>
#     </tr>
#     <tr>
#       <th>Equity(FIBBG000CWL0F5 [EXAS])</th>
#       <td>0.71%</td>
#     </tr>
#     <tr>
#       <th>Equity(FIBBG002CV4Q74 [FUBO])</th>
#       <td>0.69%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ***
#
# ## *Next Up*
#
# Part 7: [Zipline Parameter Scans](Part7-Zipline-Parameter-Scans.ipynb)
